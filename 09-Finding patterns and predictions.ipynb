# %%
import pandas as pd

# %%
air_data = pd.read_csv('AirQualityUCI.csv',na_values=['-200', -200])
air_data
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     3/10/2004  18:00:00     2.6       1360.0     150.0      11.9
# 1     3/10/2004  19:00:00     2.0       1292.0     112.0       9.4
# 2     3/10/2004  20:00:00     2.2       1402.0      88.0       9.0
# 3     3/10/2004  21:00:00     2.2       1376.0      80.0       9.2
# 4     3/10/2004  22:00:00     1.6       1272.0      51.0       6.5
# ...         ...       ...     ...          ...       ...       ...
# 9352   4/4/2005  10:00:00     3.1       1314.0       NaN      13.5
# 9353   4/4/2005  11:00:00     2.4       1163.0       NaN      11.4
# 9354   4/4/2005  12:00:00     2.4       1142.0       NaN      12.4
# 9355   4/4/2005  13:00:00     2.1       1003.0       NaN       9.5
# 9356   4/4/2005  14:00:00     2.2       1071.0       NaN      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
air_data.columns
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH', 'Unnamed: 15', 'Unnamed: 16'],
#       dtype='object')

# %%
air_data_nodate = air_data.drop(['Date','Time','Unnamed: 15','Unnamed: 16'],axis=1)
air_data_nodate
# Out:
#       CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  \
# 0        2.6       1360.0     150.0      11.9         1046.0    166.0
# 1        2.0       1292.0     112.0       9.4          955.0    103.0
# 2        2.2       1402.0      88.0       9.0          939.0    131.0
# 3        2.2       1376.0      80.0       9.2          948.0    172.0
# 4        1.6       1272.0      51.0       6.5          836.0    131.0
# ...      ...          ...       ...       ...            ...      ...
# 9352     3.1       1314.0       NaN      13.5         1101.0    472.0
# 9353     2.4       1163.0       NaN      11.4         1027.0    353.0
# 9354     2.4       1142.0       NaN      12.4         1063.0    293.0
# 9355     2.1       1003.0       NaN       9.5          961.0    235.0
# 9356     2.2       1071.0       NaN      11.9         1047.0    265.0
#
#       PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH      AH
# ...

# %%
air_data_nodate.corr()
# Out:
#                  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# CO(GT)         1.000000     0.879288  0.889734  0.931078       0.915514
# PT08.S1(CO)    0.879288     1.000000  0.790670  0.883795       0.892964
# NMHC(GT)       0.889734     0.790670  1.000000  0.902559       0.877696
# C6H6(GT)       0.931078     0.883795  0.902559  1.000000       0.981950
# PT08.S2(NMHC)  0.915514     0.892964  0.877696  0.981950       1.000000
# NOx(GT)        0.795028     0.713654  0.812685  0.718839       0.704435
# PT08.S3(NOx)  -0.703446    -0.771938 -0.771135 -0.735744      -0.796703
# NO2(GT)        0.683343     0.641529  0.731193  0.614474       0.646245
# PT08.S4(NO2)   0.630703     0.682881  0.853267  0.765731       0.777254
# PT08.S5(O3)    0.854182     0.899324  0.766723  0.865689       0.880578
# T              0.022109     0.048627  0.391587  0.198956       0.241373
# RH             0.048890     0.114606 -0.191454 -0.061681      -0.090380
# ...

# %%
#handling Time series
from datetime import date, time

# %%
air_data.dtypes
# Out:
# Date              object
# Time              object
# CO(GT)           float64
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)         float64
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                float64
# RH               float64
# AH               float64
# Unnamed: 15      float64
# Unnamed: 16      float64
# dtype: object

# %%
# to convert to datetime
pd.to_datetime(air_data['Date'] + ' ' + air_data['Time'])
# Out:
# 0      2004-03-10 18:00:00
# 1      2004-03-10 19:00:00
# 2      2004-03-10 20:00:00
# 3      2004-03-10 21:00:00
# 4      2004-03-10 22:00:00
#                ...
# 9352   2005-04-04 10:00:00
# 9353   2005-04-04 11:00:00
# 9354   2005-04-04 12:00:00
# 9355   2005-04-04 13:00:00
# 9356   2005-04-04 14:00:00
# Length: 9357, dtype: datetime64[ns]

# %%
air_data['datetime'] = pd.to_datetime(air_data['Date'] + ' ' + air_data['Time'])

# %%
air_data.plot(x='datetime', y='T')
air_data.plot(x = 'datetime', y = 'AH')
# Out:
# <Axes: xlabel='datetime'>

# %%
air_data['T'].rolling(21).mean()
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 9352    17.600000
# 9353    17.400000
# 9354    17.252381
# 9355    17.200000
# 9356    17.180952
# Name: T, Length: 9357, dtype: float64
