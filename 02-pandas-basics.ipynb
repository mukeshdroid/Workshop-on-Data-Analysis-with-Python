# %%
import pandas as pd

# %%
air_data = pd.read_csv('AirQualityUCI.csv')
air_data
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     3/10/2004  18:00:00     2.6         1360       150      11.9
# 1     3/10/2004  19:00:00     2.0         1292       112       9.4
# 2     3/10/2004  20:00:00     2.2         1402        88       9.0
# 3     3/10/2004  21:00:00     2.2         1376        80       9.2
# 4     3/10/2004  22:00:00     1.6         1272        51       6.5
# ...         ...       ...     ...          ...       ...       ...
# 9352   4/4/2005  10:00:00     3.1         1314      -200      13.5
# 9353   4/4/2005  11:00:00     2.4         1163      -200      11.4
# 9354   4/4/2005  12:00:00     2.4         1142      -200      12.4
# 9355   4/4/2005  13:00:00     2.1         1003      -200       9.5
# 9356   4/4/2005  14:00:00     2.2         1071      -200      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0              1046      166          1056      113          1692
# ...

# %%
csv_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris_data =  pd.read_csv(csv_url)
iris_data
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
col_names = ['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width','Species']
iris_data =  pd.read_csv(csv_url, names = col_names)
iris_data
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width         Species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
air_data.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  3/10/2004  18:00:00     2.6         1360       150      11.9
# 1  3/10/2004  19:00:00     2.0         1292       112       9.4
# 2  3/10/2004  20:00:00     2.2         1402        88       9.0
# 3  3/10/2004  21:00:00     2.2         1376        80       9.2
# 4  3/10/2004  22:00:00     1.6         1272        51       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0           1046      166          1056      113          1692         1268
# 1            955      103          1174       92          1559          972
# 2            939      131          1140      114          1555         1074
# 3            948      172          1092      122          1584         1203
# 4            836      131          1205      116          1490         1110
#
#       T    RH      AH  Unnamed: 15  Unnamed: 16
# 0  13.6  48.9  0.7578          NaN          NaN
# ...

# %%
air_data.tail()
# Out:
#           Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 9352  4/4/2005  10:00:00     3.1         1314      -200      13.5
# 9353  4/4/2005  11:00:00     2.4         1163      -200      11.4
# 9354  4/4/2005  12:00:00     2.4         1142      -200      12.4
# 9355  4/4/2005  13:00:00     2.1         1003      -200       9.5
# 9356  4/4/2005  14:00:00     2.2         1071      -200      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 9352           1101      472           539      190          1374
# 9353           1027      353           604      179          1264
# 9354           1063      293           603      175          1241
# 9355            961      235           702      156          1041
# 9356           1047      265           654      168          1129
#
#       PT08.S5(O3)     T    RH      AH  Unnamed: 15  Unnamed: 16
# 9352         1729  21.9  29.3  0.7568          NaN          NaN
# ...

# %%
#to get just a single columhn
air_data.RH
# Out:
# 0       48.9
# 1       47.7
# 2       54.0
# 3       60.0
# 4       59.6
#         ...
# 9352    29.3
# 9353    23.7
# 9354    18.3
# 9355    13.5
# 9356    13.1
# Name: RH, Length: 9357, dtype: float64

# %%
data.columns
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'T', 'RH', 'AH', 'Unnamed: 15', 'Unnamed: 16'],
#       dtype='object')

# %%
data.shape
# Out:
# (9357, 17)

# %%
data.dtypes
# Out:
# Date              object
# Time              object
# CO(GT)            object
# PT08.S1(CO)        int64
# NMHC(GT)           int64
# C6H6(GT)          object
# PT08.S2(NMHC)      int64
# NOx(GT)            int64
# PT08.S3(NOx)       int64
# NO2(GT)            int64
# PT08.S4(NO2)       int64
# PT08.S5(O3)        int64
# T                 object
# RH                object
# AH                object
# Unnamed: 15      float64
# Unnamed: 16      float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9357 entries, 0 to 9356
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   object
#  3   PT08.S1(CO)    9357 non-null   int64
#  4   NMHC(GT)       9357 non-null   int64
#  5   C6H6(GT)       9357 non-null   object
#  6   PT08.S2(NMHC)  9357 non-null   int64
#  7   NOx(GT)        9357 non-null   int64
#  8   PT08.S3(NOx)   9357 non-null   int64
#  9   NO2(GT)        9357 non-null   int64
#  10  PT08.S4(NO2)   9357 non-null   int64
#  11  PT08.S5(O3)    9357 non-null   int64
#  12  T              9357 non-null   object
#  13  RH             9357 non-null   object
#  14  AH             9357 non-null   object
#  15  Unnamed: 15    0 non-null      float64
#  16  Unnamed: 16    0 non-null      float64
# ...

# %% [markdown]
# <img src="https://i.stack.imgur.com/4pFuZ.png">

# %%
data.sort_index(axis=1, ascending=False).head(10)
# Out:
#    Unnamed: 16  Unnamed: 15      Time     T    RH  PT08.S5(O3)  PT08.S4(NO2)  \
# 0          NaN          NaN  18.00.00  13,6  48,9         1268          1692
# 1          NaN          NaN  19.00.00  13,3  47,7          972          1559
# 2          NaN          NaN  20.00.00  11,9  54,0         1074          1555
# 3          NaN          NaN  21.00.00  11,0  60,0         1203          1584
# 4          NaN          NaN  22.00.00  11,2  59,6         1110          1490
# 5          NaN          NaN  23.00.00  11,2  59,2          949          1393
# 6          NaN          NaN  00.00.00  11,3  56,8          733          1333
# 7          NaN          NaN  01.00.00  10,7  60,0          730          1333
# 8          NaN          NaN  02.00.00  10,7  59,7          620          1276
# 9          NaN          NaN  03.00.00  10,3  60,2          501          1235
#
#    PT08.S3(NOx)  PT08.S2(NMHC)  PT08.S1(CO)  NOx(GT)  NO2(GT)  NMHC(GT)  \
# ...

# %% [markdown]
# #### Selection by Label

# %%
# Selecting on a multi-axis by label
iris_data.loc[0:10, ['Sepal_Length', 'Petal_Length']]
# Out:
#     Sepal_Length  Petal_Length
# 0            5.1           1.4
# 1            4.9           1.4
# 2            4.7           1.3
# 3            4.6           1.5
# 4            5.0           1.4
# 5            5.4           1.7
# 6            4.6           1.4
# 7            5.0           1.5
# 8            4.4           1.4
# 9            4.9           1.5
# 10           5.4           1.5

# %%
# reduction in the dimensions of the returned object
iris_data.loc[0, ['Sepal_Length', 'Petal_Length']]
# Out:
# Sepal_Length    5.1
# Petal_Length    1.4
# Name: 0, dtype: object

# %%
# a scalar value
iris_data.loc[0, 'Petal_Length']
# Out:
# 1.4

# %%
# retrieve a column of the dataframe using a dict-like notation
iris_data['Petal_Length'].head()
# Out:
# 0    1.4
# 1    1.4
# 2    1.3
# 3    1.5
# 4    1.4
# Name: Petal_Length, dtype: float64

# %%
# retrieve a column of data by attribute
iris_data.Sepal_Length.head()
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: Sepal_Length, dtype: float64

# %%
# as a series using the loc attribute
iris_data.loc[0]
# Out:
# Sepal_Length            5.1
# Sepal_Width             3.5
# Petal_Length            1.4
# Petal_Width             0.2
# Species         Iris-setosa
# Name: 0, dtype: object

# %% [markdown]
# #### Selection by position

# %%
# Selection by position
iris_data.iloc[0:3, 0:4]
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
# getting a scalar value by position using iat
iris_data.iat[0,0]
# Out:
# 5.1

# %%
iris_data.iloc[0:3, 0:4]
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
iris_data.loc[iris_data['Species'] == 'Iris-setosa']
# Out:
#     Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
iris_data.query('Species == "Iris-setosa"')
# Out:
#     Sepal_Length  Sepal_Width  Petal_Length  Petal_Width      Species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
#drop and add columns
iris_data['Petal_ratio'] = iris_data.Petal_Length / iris_data.Petal_Width
iris_data
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width         Species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      Petal_ratio
# 0       7.000000
# 1       7.000000
# 2       6.500000
# ...

# %%
iris_data.drop('Petal_ratio',axis=1)
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width         Species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]
